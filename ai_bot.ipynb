# %% [markdown]
# <a href="https://colab.research.google.com/github/Skit-025/Project-1/blob/main/ai_bot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
#requests lib imported for http requests and responses
#this will make my program eligble to communicate with  Hugging face api

# %%
import os
#importing os as i will save my hf token somewhere in safer place in my virtual environment

# %%
API_URL=r"http://router.huggingface.co/v1/chat/completions"
#setting the url to dynamic model detection and route to an appropriaate model for data retrival

# %%
Name=input('Enter with whom you want to communicate: ')

# %%
from IPython.core import payload
def query(message, Name="DefaultName"):
    # Decide max_token based on keywords in message
    keywords = ['generate','create','give','provide','display',"show","print"]
    max_token = 500 if any(word in message for word in keywords) else 150

    payload = {
        'model': 'metallama/Meta-llama-3-8B-Instruct',
        'messages': [
            {
                'role': 'system',
                'content': f'You are {Name}, talk to the front person just the way in which {Name} would have talked'
            },
            {
                'role': 'user',
                'content': message
            }
        ],
        'max_token': max_token
    }
    return payload
